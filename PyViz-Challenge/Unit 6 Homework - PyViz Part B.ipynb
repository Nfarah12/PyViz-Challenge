# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Using the read_csv function and Path module, create a DataFrame 
# by importing the sfo_neighborhoods_census_data.csv file from the Resources folder
neighborhoods_coordinates_df = pd.read_csv(Path(r"C:\Users\nasir\OneDrive\Desktop\Fintech\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\06-PyViz\Unit 6 Homework\Instructions\Starter_Code\Resources/neighborhoods_coordinates.csv")).drop_duplicates()
sfo_data_df = pd.read_csv(Path(r"C:\Users\nasir\OneDrive\Desktop\Fintech\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\06-PyViz\Unit 6 Homework\Instructions\Starter_Code\Resources/sfo_neighborhoods_census_data.csv")).drop_duplicates()
housing_per_year_df = pd.read_csv(Path(r"C:\Users\nasir\OneDrive\Desktop\Fintech\UTOR-VIRT-FIN-PT-08-2023-U-LOLC\06-PyViz\Unit 6 Homework\Instructions\Starter_Code\Resources/housing_per_year.csv")).drop_duplicates()

# Review a sample of ten rows of the DataFrame
display(sfo_data_df.sample(10))
display(housing_per_year_df.head())
# Out:
#      year                neighborhood  sale_price_sqr_foot  housing_units  \
# 209  2013                 North Beach           393.717335         378401
# 194  2013                Hayes Valley           491.589261         378401
# 263  2014                 Mission Bay           220.111087         380348
# 5    2010              Central Sunset           418.172493         372560
# 142  2012         Lake --The Presidio           380.521484         376454
# 370  2016                Inner Sunset           445.923828         384242
# 84   2011  Jordan Park/Laurel Heights           610.766663         374507
# 349  2015            Western Addition           481.469244         382295
# 284  2014              Telegraph Hill           708.193032         380348
# 216  2013                    Parkside           364.624653         378401
#
#      gross_rent
# 209        2971
# 194        2971
# 263        3528
# 5          1239
# 142        2324
# 370        4390
# 84         1530
# ...

# %%
# Create a DataFrame consisting of the CityName, PopulationCount, Latitude and Longitude columns
neighborhood_sale_price_sqr_foot_df = sfo_data_df[["neighborhood", "sale_price_sqr_foot"]]

# Review the DataFrame
neighborhood_sale_price_sqr_foot_df.head()
# Out:
#        neighborhood  sale_price_sqr_foot
# 0      Alamo Square           291.182945
# 1        Anza Vista           267.932583
# 2           Bayview           170.098665
# 3  Buena Vista Park           347.394919
# 4  Central Richmond           319.027623

# %%
# Create a numerical aggregation that groups the data by the year and then averages the results.
#housing_units_by_year = sfo_data_df.groupby("year").mean()

neighborhood_sale_price_Ave_df = (neighborhood_sale_price_sqr_foot_df
    .groupby("neighborhood")
    .mean()
    .sort_values("neighborhood")
)
# View the result
neighborhood_sale_price_Ave_df
# Out:
#                     sale_price_sqr_foot
# neighborhood
# Alamo Square                 366.020712
# Anza Vista                   373.382198
# Bayview                      204.588623
# Bayview Heights              590.792839
# Bernal Heights               576.746488
# ...                                 ...
# West Portal                  498.488485
# Western Addition             307.562201
# Westwood Highlands           533.703935
# Westwood Park                687.087575
# Yerba Buena                  576.709848
#
# [73 rows x 1 columns]

# %%
# Review the DataFrame
neighborhoods_coordinates_df
# Out:
#           Neighborhood        Lat         Lon
# 0         Alamo Square  37.791012 -122.402100
# 1           Anza Vista  37.779598 -122.443451
# 2              Bayview  37.734670 -122.401060
# 3      Bayview Heights  37.728740 -122.410980
# 4       Bernal Heights  37.728630 -122.443050
# ..                 ...        ...         ...
# 68         West Portal  37.740260 -122.463880
# 69    Western Addition  37.792980 -122.435790
# 70  Westwood Highlands  37.734700 -122.456854
# 71       Westwood Park  37.734150 -122.457000
# 72         Yerba Buena  37.792980 -122.396360
#
# [73 rows x 3 columns]

# %%
# Set the index as the 'Neighborhood' column
neighborhoods_coordinates_df = neighborhoods_coordinates_df.set_index(neighborhoods_coordinates_df["Neighborhood"])

neighborhoods_coordinates_df.head()
# Out:
#                     Neighborhood        Lat         Lon
# Neighborhood
# Alamo Square        Alamo Square  37.791012 -122.402100
# Anza Vista            Anza Vista  37.779598 -122.443451
# Bayview                  Bayview  37.734670 -122.401060
# Bayview Heights  Bayview Heights  37.728740 -122.410980
# Bernal Heights    Bernal Heights  37.728630 -122.443050

# %%
neighborhoods_coordinates_df
# Out:
#                           Neighborhood        Lat         Lon
# Neighborhood
# Alamo Square              Alamo Square  37.791012 -122.402100
# Anza Vista                  Anza Vista  37.779598 -122.443451
# Bayview                        Bayview  37.734670 -122.401060
# Bayview Heights        Bayview Heights  37.728740 -122.410980
# Bernal Heights          Bernal Heights  37.728630 -122.443050
# ...                                ...        ...         ...
# West Portal                West Portal  37.740260 -122.463880
# Western Addition      Western Addition  37.792980 -122.435790
# Westwood Highlands  Westwood Highlands  37.734700 -122.456854
# Westwood Park            Westwood Park  37.734150 -122.457000
# Yerba Buena                Yerba Buena  37.792980 -122.396360
#
# [73 rows x 3 columns]

# %%
# Concatenate the two DataFrames by columns and perform an inner join
column_joined_data = pd.concat([neighborhoods_coordinates_df, neighborhood_sale_price_Ave_df], axis="columns", join="inner")
column_joined_data
# Out:
#                           Neighborhood        Lat         Lon  \
# Alamo Square              Alamo Square  37.791012 -122.402100
# Anza Vista                  Anza Vista  37.779598 -122.443451
# Bayview                        Bayview  37.734670 -122.401060
# Bayview Heights        Bayview Heights  37.728740 -122.410980
# Buena Vista Park      Buena Vista Park  37.768160 -122.439330
# ...                                ...        ...         ...
# West Portal                West Portal  37.740260 -122.463880
# Western Addition      Western Addition  37.792980 -122.435790
# Westwood Highlands  Westwood Highlands  37.734700 -122.456854
# Westwood Park            Westwood Park  37.734150 -122.457000
# Yerba Buena                Yerba Buena  37.792980 -122.396360
#
#                     sale_price_sqr_foot
# Alamo Square                 366.020712
# Anza Vista                   373.382198
# Bayview                      204.588623
# Bayview Heights              590.792839
# ...

# %%
column_joined_data=column_joined_data.reset_index(drop=True)

# %%
column_joined_data
# Out:
#           Neighborhood        Lat         Lon  sale_price_sqr_foot
# 0         Alamo Square  37.791012 -122.402100           366.020712
# 1           Anza Vista  37.779598 -122.443451           373.382198
# 2              Bayview  37.734670 -122.401060           204.588623
# 3      Bayview Heights  37.728740 -122.410980           590.792839
# 4     Buena Vista Park  37.768160 -122.439330           452.680591
# ..                 ...        ...         ...                  ...
# 64         West Portal  37.740260 -122.463880           498.488485
# 65    Western Addition  37.792980 -122.435790           307.562201
# 66  Westwood Highlands  37.734700 -122.456854           533.703935
# 67       Westwood Park  37.734150 -122.457000           687.087575
# 68         Yerba Buena  37.792980 -122.396360           576.709848
#
# [69 rows x 4 columns]

# %%
# Drop unneede cloumns
#column_appended_data = column_appended_data.drop(columns=["Neighborhood"])
#column_appended_data.head()

# %%
Average_sale_price_by_neighborhood = column_joined_data.hvplot.points(
    'Lon', 
    'Lat', 
    geo=True, 
    color='Neighborhood',
    size = 'sale_price_sqr_foot',
    alpha=0.8,
    tiles='OSM',
    frame_width = 700,
    frame_height = 500
    )
# Show the plot
Average_sale_price_by_neighborhood
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (Neighborhood,sale_price_sqr_foot)
